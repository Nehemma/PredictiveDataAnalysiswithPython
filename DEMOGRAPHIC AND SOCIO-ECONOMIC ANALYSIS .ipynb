# %% [markdown]
# ## <font > <center> <u> <b> 📍 📍 Demographic and Socio-economic situation analysis. 📍 📍</b> </u> </center> </font>
#
# ### `Table of Contents`
#
# 1. Exploratory Data Analysis
#     - Loading the training and test datasets
#     - Variable Identification and Typecasting
#     - Plotting the variables of interest
#     - Checking on the data distribution
#     - Data Cleaning
# 2. Modeling
#     - Scaling the datasets
#     - Compiling the model
#     - Training the model

# %% [markdown]
# ### <center> Importing relevant libraries to be used in the analysis

# %%
import pandas as pd #data reading library
import matplotlib.pyplot as plt #ploting library
import numpy as np #mathematical operations library
import seaborn as sns

# %% [markdown]
# ### <center> Importing The train and validation datasets for exploration

# %%
## The train dataset ##
Train_data = pd.read_csv('Train_data.csv')

# %%
Validation_data = pd.read_csv('Validation.csv')

# %% [markdown]
# ### <center> Understanding the dataset
# - Train dataset

# %%
print('The train dataset contains',Train_data.shape[1], 'columns and',Train_data.shape[0], 'observations')

print('The Validation dataset contains',Validation_data.shape[1], 'columns and',Validation_data.shape[0], 'observations. The test dataset is 19% of the total observations')
# Out:
# The train dataset contains 81 columns and 3097 observations
# The Validation dataset contains 81 columns and 720 observations. The test dataset is 19% of the total observations

# %% [markdown]
# #### Viewing the 1st 4 observations

# %%
Train_data.head(4)
# Out:
#       ID  galactic year                       galaxy  \
# 0  10065        1002001                     Antlia B
# 1  10087         999000  KKH 11 (ZOAG G135.74-04.53)
# 2  10141         993012                 Leo IV Dwarf
# 3  10168         995006                      NGC 185
#
#    existence expectancy index  existence expectancy at birth  \
# 0                    0.624015                      56.397241
# 1                    0.970048                      80.924094
# 2                    0.995540                      82.441006
# 3                    1.004362                      75.635986
#
#    Gross income per capita  Income Index  \
# 0              17649.87156      0.458599
# 1              11409.94296      0.757218
# 2              58774.29343      1.032429
# 3              34960.41911      0.707776
#
#    Expected years of education (galactic years)  \
# 0                                      7.857841
# 1                                     15.869798
# ...

# %%
Validation_data.head(4)
# Out:
#        ID  galactic year                  galaxy  existence expectancy index  \
# 0  886447        1004004  Andromeda Galaxy (M31)                    0.803915
# 1  687564        1005006  Andromeda Galaxy (M31)                    0.860011
# 2  494935        1006009  Andromeda Galaxy (M31)                    0.810644
# 3  378919        1015056  Andromeda Galaxy (M31)                    0.837170
#
#    existence expectancy at birth  Gross income per capita  Income Index  \
# 0                      82.718434              17299.57148      0.691448
# 1                      73.682279              24971.71631      0.669550
# 2                      68.456526              15943.82977      0.766118
# 3                      68.742404              20952.63665      0.757196
#
#    Expected years of education (galactic years)  \
# 0                                     16.083635
# 1                                     12.858577
# 2                                     14.236676
# ...

# %% [markdown]
# #### Viewing the last 4 observations

# %%
Train_data.tail(4)
# Out:
#           ID  galactic year                                 galaxy  \
# 3093  993243        1004004                                 NGC 55
# 3094  994215        1004004  Small Magellanic Cloud (SMC, NGC 292)
# 3095  997864        1004004                         Andromeda XXIV
# 3096  998085        1005006                               Maffei 2
#
#       existence expectancy index  existence expectancy at birth  \
# 3093                    0.942579                      84.852778
# 3094                    1.013720                      86.117546
# 3095                    0.545461                      58.674229
# 3096                    0.961072                      78.548767
#
#       Gross income per capita  Income Index  \
# 3093              55945.54506      1.128565
# 3094              17258.34503      0.872451
# 3095              11367.55522      0.586294
# 3096              18064.60684      0.672132
#
#       Expected years of education (galactic years)  \
# ...

# %%
Validation_data.tail(4)
# Out:
#          ID  galactic year                                galaxy  \
# 716   17112        1003002  Wolf-Lundmark-Melotte (WLM, DDO 221)
# 717  583782        1004004  Wolf-Lundmark-Melotte (WLM, DDO 221)
# 718  823832        1005006  Wolf-Lundmark-Melotte (WLM, DDO 221)
# 719  872042        1006009  Wolf-Lundmark-Melotte (WLM, DDO 221)
#
#      existence expectancy index  existence expectancy at birth  \
# 716                    0.628426                      58.772174
# 717                    0.603825                      58.301528
# 718                    0.574464                      53.416728
# 719                    0.614594                      58.751698
#
#      Gross income per capita  Income Index  \
# 716              26523.82527      0.572390
# 717              10659.49479      0.629569
# 718              23157.55806      0.627428
# 719              24016.06785      0.623884
#
#      Expected years of education (galactic years)  \
# ...

# %% [markdown]
# ### <center> Variable Identification and Typecasting

# %% [markdown]
# ### Integer Data Type

# %%
Train_data.dtypes[Train_data.dtypes== 'int64']
# Out:
# ID               int64
# galactic year    int64
# dtype: object

# %% [markdown]
# summary
#
# * ID and galactic year are whole numbers hence okay as integers

# %%
Train_data.dtypes[Train_data.dtypes == 'object']
# Out:
# galaxy    object
# dtype: object

# %% [markdown]
# summary
#
# * Galaxy is the object variable which is okay as it contains letters.

# %%
Train_data.dtypes[Train_data.dtypes == 'float']
# Out:
# existence expectancy index                                                          float64
# existence expectancy at birth                                                       float64
# Gross income per capita                                                             float64
# Income Index                                                                        float64
# Expected years of education (galactic years)                                        float64
# Mean years of education (galactic years)                                            float64
# Intergalactic Development Index (IDI)                                               float64
# Education Index                                                                     float64
# Intergalactic Development Index (IDI), Rank                                         float64
# Population using at least basic drinking-water services (%)                         float64
# ...

# %% [markdown]
# Summary
# * The data has 78 varialbles that have float values

# %% [markdown]
# #### Generating the descriptive statistics

# %%
Train_data.describe()
# Out:
#                   ID  galactic year  existence expectancy index  \
# count    3097.000000   3.097000e+03                 3096.000000
# mean   157659.407168   9.984641e+05                    0.863193
# std    230716.474733   5.417848e+03                    0.164595
# min     10065.000000   9.900250e+05                    0.227890
# 25%     38554.000000   9.940090e+05                    0.749559
# 50%     67570.000000   9.980010e+05                    0.899075
# 75%     95992.000000   1.003002e+06                    0.985961
# max    998085.000000   1.011030e+06                    1.204456
#
#        existence expectancy at birth  Gross income per capita  Income Index  \
# count                    3096.000000              3069.000000   3069.000000
# mean                       76.197777             31175.236021      0.819082
# std                        10.539559             18574.375226      0.194201
# min                        34.244062              -126.906522      0.292001
# ...

# %% [markdown]
# In the data description, the object variable which is the galaxy variable is aoutomatically ommited.

# %% [markdown]
# ### <center> Getting the variables of interest

# %% [markdown]
# #### Correlation plot

# %%
corr=Train_data.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_b049feda_535b_11ed_beca_6480999d41darow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b049feda_535b_11ed_beca_6480999d41darow0_col1 {
#             background-color:  #f7ad90;
#             color:  #000000;
#         }    #T_b049feda_535b_11ed_beca_6480999d41darow0_col2 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_b049feda_535b_11ed_beca_6480999d41darow0_col3 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_b049feda_535b_11ed_beca_6480999d41darow0_col4 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_b049feda_535b_11ed_beca_6480999d41darow0_col5 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_b049feda_535b_11ed_beca_6480999d41darow0_col6 {
#             background-color:  #e6d7cf;
#             color:  #000000;
# ...

# %% [markdown]
# Summary:
#
# Variables that are strongly correlated to **Well-being Index** positively are
#
#    * Income Index
#    * Expected years of education (galactic years)
#    * Mean years of education (galactic years)
#    * Intergalactic Development Index (IDI)
#    * Education Index
#    * Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))
#    * Mean years of education, female (galactic years)
#    * Mean years of education, male (galactic years)
#    * Expected years of education, female (galactic years)
#    * Expected years of education, male (galactic years)
#    * Estimated gross galactic income per capita, female
#    * Interstellar Data Net users, total (% of population)
#    * Intergalactic Development Index (IDI), female
#    * Intergalactic Development Index (IDI), male
#
#  Variables that are strongly correlated to **Well-being Index** negatively are
#    * Intergalactic Development Index (IDI), Rank
#    * Gender Inequality Index (GII)
#    * Intergalactic Development Index (IDI), male, Rank
#    * Intergalactic Development Index (IDI), female, Rank

# %% [markdown]
# ### <center> Treating missing values
# #### Calculating the percentages of missing values for every variable in the Training dataset

# %%
Train_data.isna().sum()/(Train_data.shape[0])*100
# Out:
# ID                                                                                   0.000000
# galactic year                                                                        0.000000
# galaxy                                                                               0.000000
# existence expectancy index                                                           0.032289
# existence expectancy at birth                                                        0.032289
# Gross income per capita                                                              0.904101
# Income Index                                                                         0.904101
# Expected years of education (galactic years)                                         4.165321
# Mean years of education (galactic years)                                            11.462706
# Intergalactic Development Index (IDI)                                               12.302228
# ...

# %%
Train_data1=Train_data.fillna(method="bfill")

# %%
Validation_data1 = Validation_data.fillna(method="bfill")

# %% [markdown]
# ### <center> Plotting variables of interests

# %%
income_index = Train_data1['Income Index']
Well_Being_Index = Train_data1['Well-Being Index']

# %%
corr=Train_data1[['Income Index','Education Index','Gender Inequality Index (GII)','Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))','Well-Being Index']].corr()
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,
           cmap='Greens')
plt.title('Correlation matrix', fontsize=20)
plt.show();

# %%
color= ['blue']
Train_data1.plot.scatter(x='Well-Being Index',y='Income Index',marker='o',c=color)
plt.title('Income index vs Well being index',fontsize=20)
plt.ylabel('Income')
plt.xlabel('Well being')
plt.show()

# %% [markdown]
# The above scatter plot shows that there is a positive relationship between income index and well being index.

# %%
color = ['green']
Train_data1.plot.scatter(x='Well-Being Index',y='Education Index',marker='o',c=color)
plt.title('Education index vs Well being index',fontsize=20)
plt.ylabel('Education')
plt.xlabel('Well being')
plt.show()

# %% [markdown]
# The above scatter plot shows that there is a positive relationship between Education index and well being index.

# %%
color = ['red']
Train_data1.plot.scatter(x='Well-Being Index',y='Gender Inequality Index (GII)',marker='o',c=color)
plt.title('Gender Inequality vs Well being index',fontsize=20)
plt.ylabel('Gender Inequality')
plt.xlabel('Well Being')
plt.show()

# %% [markdown]
# From the above plot, and the correlation table, it was evident that gender inequality affects the well-being index negatively.
# This shows that gender inequality leads to a poor or low well being index.

# %%
color = ['black']
Train_data1.plot.scatter(x='Well-Being Index',y='Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))',marker='o',c=color)
plt.title('Old Age Dependency vs Well being index',fontsize=20)
plt.ylabel('Old Age Dependency')
plt.xlabel('Well Being')
plt.show()

# %% [markdown]
# From the above graph, it is evident that there is a weak positive relationship between Old Age Dependency and well being.
# This is almost a negative relationship. This may indicate that the higher the number of dependants, then the lower the well being index.

# %% [markdown]
# ### <center> Modeling

# %% [markdown]
# #### Scaling the dataset using a min-max scaler

# %%
# importing the minimum maximum scaler scaler to scale the dataset
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
# Creating a copy of the dataset
Train_data2 = Train_data1.copy()

# %%
from sklearn.model_selection import train_test_split

# %%
Train_data2.head(1)
# Out:
#       ID  galactic year    galaxy  existence expectancy index  \
# 0  10065        1002001  Antlia B                    0.624015
#
#    existence expectancy at birth  Gross income per capita  Income Index  \
# 0                      56.397241              17649.87156      0.458599
#
#    Expected years of education (galactic years)  \
# 0                                      7.857841
#
#    Mean years of education (galactic years)  \
# 0                                  5.196527
#
#    Intergalactic Development Index (IDI)  ...  \
# 0                               0.507534  ...
#
#    Intergalactic Development Index (IDI), female  \
# 0                                       0.458973
#
#    Intergalactic Development Index (IDI), male  \
# 0                                     0.468234
#
#    Gender Development Index (GDI)  \
# 0                        0.854562
#
#    Intergalactic Development Index (IDI), female, Rank  \
# 0                                         176.350623
#
# ...

# %%
Train_data2.drop('ID', inplace=True, axis=1)

# %%
Train_data2.drop('galactic year', inplace=True, axis=1)

# %%
Train_data2.drop('galaxy', inplace=True, axis=1)

# %%
Train_data2.head(2)
# Out:
#    existence expectancy index  existence expectancy at birth  \
# 0                    0.624015                      56.397241
# 1                    0.970048                      80.924094
#
#    Gross income per capita  Income Index  \
# 0              17649.87156      0.458599
# 1              11409.94296      0.757218
#
#    Expected years of education (galactic years)  \
# 0                                      7.857841
# 1                                     15.869798
#
#    Mean years of education (galactic years)  \
# 0                                  5.196527
# 1                                 13.065734
#
#    Intergalactic Development Index (IDI)  Education Index  \
# 0                               0.507534         0.471400
# 1                               0.807108         0.837559
#
#    Intergalactic Development Index (IDI), Rank  \
# 0                                   247.196654
# 1                                   137.299057
#
# ...

# %%
lab = preprocessing.LabelEncoder()
y_transformed = lab.fit_transform(Train_data2['Well-Being Index'])

# %%
Train_data2.dropna(inplace=True)

# %%
from sklearn import preprocessing
from sklearn import utils

# %%
x_train, x_test, y_train,y_test = train_test_split(Train_data2.loc[:, Train_data2.columns!='Well-Being Index'],y_transformed,test_size=0.20,random_state=21)
print('Shape of Training Xs:{}'.format(x_train.shape))
print('Shape of Test Xs:{}'.format(x_test.shape))
print('Shape of Training y:{}'.format(y_train.shape))
print('Shape of Test y:{}'.format(y_test.shape))
# Out:
# Shape of Training Xs:(2464, 77)
# Shape of Test Xs:(617, 77)
# Shape of Training y:(2464,)
# Shape of Test y:(617,)

# %%
Train_Scaled=scaler.fit_transform(x_train.loc[:, x_train.columns!='galaxy'])

# %%
Test_Scaled=scaler.fit_transform(x_test.loc[:, x_test.columns!='galaxy'])

# %%
from sklearn import linear_model

# %%
logr = linear_model.LogisticRegression()

# %%
logr.fit(x_train,y_train)
# Out:
# C:\Users\user\.conda\Anaconda2\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\user\.conda\Anaconda2\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\Users\user\.conda\Anaconda2\lib\site-packages\sklearn\svm\base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred = logr.predict(x_test)
len(y_pred)
# Out:
# 617

# %%
lab = preprocessing.LabelEncoder()
y_test = lab.fit_transform(y_test)
